# %% [markdown]
# **1. Project Structure:**
#
# * Create a new directory for SimSightsAI
# * Inside my project directory, create subdirectories for different functionalities (optional but recommended for organization):
#     * data_handler/ (for data loading and cleaning functions)
#     * visualization/ (for visualization functions)
#     * modeling/ (for machine learning functions)
#     * explanations/ (optional, for explainer functions)
#
# **2. Initial Flask Application (app.py):**
#
# * Create a file named `app.py` in my project directory.
# * This file will serve as the entry point for my Flask application. Here's a basic structure:
#
# ```python
# from flask import Flask, render_template, request
#
# app = Flask(__name__)
#
# @app.route("/")
# def home():
#     return render_template("index.html")  # Replace with actual content or logic
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# **3. Simple User Interface (Optional):**
#
# * Create a basic HTML file named `index.html` in my project directory (content will be replaced later).
# * This file can initially display instructions for users on how to upload data and interact with the platform.
#
# **4. Running the Application:**
#
# * Open a terminal or command prompt and navigate to my project directory.
# * Run Flask application using:
#
# ```bash
# python app.py
# ```
#
# * This will start the development server, and I can usually access my application at `http://127.0.0.1:5000/` in my web browser. I'll see a basic page based on my `index.html` content.
#
#
# Next steps can involve:
#
# * Implementing the `data_handler.py` functions to handle data upload, cleaning, and pre-processing (start with basic cleaning).
# * Developing the `visualization.py` functions to generate histograms and scatterplots for data exploration.
# * Defining routes in `app.py` to handle data upload and visualization selection.
# * Testing my functionalities step-by-step to ensure they work as expected.
#
# Remember, this is an iterative process. Start with the core functionalities, test them thoroughly, and gradually add more complexity based on my plan.
